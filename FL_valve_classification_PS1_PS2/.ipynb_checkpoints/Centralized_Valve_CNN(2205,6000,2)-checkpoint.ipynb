# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load and preprocess the data
def load_data():
    print("Loading data...")
    X_ps1 = pd.read_csv(r"C:\Users\HP\Downloads\Mahak_btp\VSCode_FL_Mahak\FL_Valve_Classification\PS1.csv", header=None).values
    X_ps2 = pd.read_csv(r"C:\Users\HP\Downloads\Mahak_btp\VSCode_FL_Mahak\FL_Valve_Classification\PS2.csv", header=None).values
    y = pd.read_csv(r"C:\Users\HP\Downloads\Mahak_btp\VSCode_FL_Mahak\FL_Valve_Classification\valve_target_encoded.csv", header=None).values.flatten()
    print(f"Data shapes: X_ps1={X_ps1.shape}, X_ps2={X_ps2.shape}, y={y.shape}")

    # Combine features from PS1 and PS2
    X_combined = np.concatenate([X_ps1, X_ps2], axis=1)
    print(f"Combined data shape: {X_combined.shape}")

    # Normalize features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_combined)
    print("Data normalization complete.")

    # Reshape to (samples, time_steps, features) for CNN input
    X_reshaped = X_scaled.reshape(2205, 6000, 2)  # (samples, time_steps, features)
    print(f"Reshaped data for CNN: {X_reshaped.shape}")

    return X_reshaped, y


# Define the CNN model structure
def create_model(input_shape):
    print("Creating CNN model...")
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=input_shape),
#         tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'),
#         tf.keras.layers.MaxPooling1D(pool_size=2),
#         tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Conv1D(128, kernel_size=3, activation='relu', padding='same'),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Conv1D(256, kernel_size=3, activation='relu', padding='same'),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(4, activation="softmax")  # For 4 classes
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    print("Model created successfully.")
    return model


# Main model training and evaluation
def train_and_evaluate_model():
    # Load data
    X_total, y_total = load_data()

    # Split the data for train and test
    print("Splitting data into train and test sets...")
    X_train, X_test, y_train, y_test = train_test_split(X_total, y_total, test_size=0.10, random_state=104, stratify=y_total)
    print(f"Training data shape: {X_train.shape}, Testing data shape: {X_test.shape}")

    # Create model
    model = create_model(input_shape=(6000, 2))

    # Train model
    history = model.fit(X_train, y_train, epochs=80, batch_size=32, validation_data=(X_test, y_test))

    # Evaluate model
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

    # Plot training history (accuracy and loss vs epochs)
    plot_training_history(history)

    # Confusion Matrix
    plot_confusion_matrix(model, X_test, y_test)


# Plot training history (accuracy and loss)
def plot_training_history(history):
    # Plot accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Test Accuracy')
    plt.title('Accuracy vs Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('Loss vs Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()


# Plot confusion matrix
def plot_confusion_matrix(model, X_test, y_test):
    y_pred = np.argmax(model.predict(X_test), axis=1)
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()


if __name__ == "__main__":
    train_and_evaluate_model()
# Out:
# Loading data...
# Data shapes: X_ps1=(2205, 6000), X_ps2=(2205, 6000), y=(2205,)
# Combined data shape: (2205, 12000)
# Data normalization complete.
# Reshaped data for CNN: (2205, 6000, 2)
# Splitting data into train and test sets...
# Training data shape: (1984, 6000, 2), Testing data shape: (221, 6000, 2)
# Creating CNN model...
# Model created successfully.
# Epoch 1/100
# 62/62 [==============================] - 97s 1s/step - loss: 1.1274 - accuracy: 0.5736 - val_loss: 0.8537 - val_accuracy: 0.7104
# Epoch 2/100
# 62/62 [==============================] - 80s 1s/step - loss: 0.6025 - accuracy: 0.7742 - val_loss: 0.5007 - val_accuracy: 0.8733
# Epoch 3/100
# 62/62 [==============================] - 74s 1s/step - loss: 0.3723 - accuracy: 0.8710 - val_loss: 0.3088 - val_accuracy: 0.9005
# Epoch 4/100
# 62/62 [==============================] - 56s 896ms/step - loss: 0.2512 - accuracy: 0.9088 - val_loss: 0.2631 - val_accuracy: 0.9321
# Epoch 5/100
# 62/62 [==============================] - 55s 890ms/step - loss: 0.2175 - accuracy: 0.9047 - val_loss: 0.2243 - val_accuracy: 0.9095
# Epoch 6/100
# 62/62 [==============================] - 76s 1s/step - loss: 0.1767 - accuracy: 0.9199 - val_loss: 0.2053 - val_accuracy: 0.9140
# Epoch 7/100
# 62/62 [==============================] - 78s 1s/step - loss: 0.1589 - accuracy: 0.9269 - val_loss: 0.2370 - val_accuracy: 0.9050
# Epoch 8/100
# 62/62 [==============================] - 80s 1s/step - loss: 0.1646 - accuracy: 0.9274 - val_loss: 0.1961 - val_accuracy: 0.8824
# Epoch 9/100
# 62/62 [==============================] - 70s 1s/step - loss: 0.1502 - accuracy: 0.9244 - val_loss: 0.1871 - val_accuracy: 0.8869
# Epoch 10/100
# 62/62 [==============================] - 57s 924ms/step - loss: 0.1397 - accuracy: 0.9294 - val_loss: 0.1672 - val_accuracy: 0.9050
# Epoch 11/100
# 62/62 [==============================] - 57s 927ms/step - loss: 0.1314 - accuracy: 0.9395 - val_loss: 0.1549 - val_accuracy: 0.9186
# Epoch 12/100
# 62/62 [==============================] - 29s 469ms/step - loss: 0.1236 - accuracy: 0.9390 - val_loss: 0.1465 - val_accuracy: 0.9276
# Epoch 13/100
# 62/62 [==============================] - 28s 446ms/step - loss: 0.1329 - accuracy: 0.9325 - val_loss: 0.1871 - val_accuracy: 0.9231
# Epoch 14/100
# 62/62 [==============================] - 28s 451ms/step - loss: 0.1465 - accuracy: 0.9390 - val_loss: 0.1415 - val_accuracy: 0.9231
# Epoch 15/100
# 62/62 [==============================] - 30s 479ms/step - loss: 0.0967 - accuracy: 0.9556 - val_loss: 0.0883 - val_accuracy: 0.9819
# Epoch 16/100
# 62/62 [==============================] - 29s 468ms/step - loss: 0.0769 - accuracy: 0.9748 - val_loss: 0.0628 - val_accuracy: 0.9864
# Epoch 17/100
# 62/62 [==============================] - 52s 842ms/step - loss: 0.0510 - accuracy: 0.9819 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 18/100
# 62/62 [==============================] - 53s 850ms/step - loss: 0.0203 - accuracy: 0.9945 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 19/100
# 62/62 [==============================] - 46s 733ms/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 20/100
# 62/62 [==============================] - 52s 833ms/step - loss: 0.0067 - accuracy: 0.9990 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 21/100
# 62/62 [==============================] - 45s 723ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 22/100
# 62/62 [==============================] - 52s 845ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 23/100
# 62/62 [==============================] - 48s 774ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 24/100
# 62/62 [==============================] - 27s 440ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 25/100
# 62/62 [==============================] - 27s 442ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 26/100
# 62/62 [==============================] - 28s 449ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 27/100
# 62/62 [==============================] - 28s 453ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 28/100
# 62/62 [==============================] - 28s 458ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 29/100
# 62/62 [==============================] - 28s 454ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9955
# Epoch 30/100
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 31/100
# 62/62 [==============================] - 28s 454ms/step - loss: 7.5030e-04 - accuracy: 0.9995 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 32/100
# 62/62 [==============================] - 28s 460ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 33/100
# 62/62 [==============================] - 29s 475ms/step - loss: 3.8753e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9955
# Epoch 34/100
# 62/62 [==============================] - 45s 731ms/step - loss: 5.5499e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9955
# Epoch 35/100
# 62/62 [==============================] - 50s 808ms/step - loss: 3.8293e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 36/100
# 62/62 [==============================] - 50s 806ms/step - loss: 5.7193e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9955
# Epoch 37/100
# 62/62 [==============================] - 42s 676ms/step - loss: 4.0266e-04 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 0.9955
# Epoch 38/100
# 62/62 [==============================] - 53s 851ms/step - loss: 3.8646e-04 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9955
# Epoch 39/100
# 62/62 [==============================] - 53s 851ms/step - loss: 7.6756e-04 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 40/100
# 62/62 [==============================] - 50s 806ms/step - loss: 2.5279e-04 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 0.9955
# Epoch 41/100
# 62/62 [==============================] - 28s 448ms/step - loss: 2.1288e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9955
# Epoch 42/100
# 62/62 [==============================] - 28s 447ms/step - loss: 5.6051e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9955
# Epoch 43/100
# 62/62 [==============================] - 28s 446ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0260 - val_accuracy: 0.9910
# Epoch 44/100
# 62/62 [==============================] - 28s 448ms/step - loss: 5.8005e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 45/100
# 62/62 [==============================] - 28s 446ms/step - loss: 2.0138e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 46/100
# 62/62 [==============================] - 28s 445ms/step - loss: 3.9598e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 47/100
# 62/62 [==============================] - 28s 449ms/step - loss: 2.2614e-04 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9955
# Epoch 48/100
# 62/62 [==============================] - 28s 449ms/step - loss: 1.8952e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 49/100
# 62/62 [==============================] - 28s 450ms/step - loss: 1.7965e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 50/100
# 62/62 [==============================] - 28s 453ms/step - loss: 1.0925e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 51/100
# 62/62 [==============================] - 28s 460ms/step - loss: 9.1878e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 52/100
# 62/62 [==============================] - 28s 451ms/step - loss: 3.4883e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 53/100
# 62/62 [==============================] - 28s 450ms/step - loss: 8.5021e-05 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 54/100
# 62/62 [==============================] - 28s 453ms/step - loss: 1.1924e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 55/100
# 62/62 [==============================] - 27s 440ms/step - loss: 8.2244e-05 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 56/100
# 62/62 [==============================] - 28s 448ms/step - loss: 1.7306e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 57/100
# 43/62 [===================>..........] - ETA: 8s - loss: 9.3760e-05 - accuracy: 1.0000
